# %% [markdown]
# ## Sparks Foundation
# ## Name: Eslam Mohamed Farouk
# ## Task 04 : Exploratory Data Analysis - Terrorism (Level - Intermediate)

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading CSV File

# %%
terrorism_df = pd.read_csv(r"D:\globalterrorismdb_0718dist.csv", encoding='latin1')
terrorism_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ### Size of Array

# %%
terrorism_df.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Total Number of Missing Values

# %%
terrorism_df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# ### Checking for Datatypes

# %%
terrorism_df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %% [markdown]
# ### Attribute name

# %%
terrorism_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ### Renaming the Column Names

# %%
terrorism_df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','target1':'Target',
                             'provstate':'State','region_txt':'Region','attacktype1_txt':'AttackType',
                             'nkill':'Kills','nwound':'Wounded','summary':'Summary',
                             'natlty1_txt':'Nationality','gname':'Group','targtype1_txt':'TargetType',
                             'weaptype1_txt':'WeaponType','motive':'Motive','city':'City','latitude':'Latitude',
                             'longitude':'Longitude'},inplace=True)

# %%
terrorism_df.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
global_terrorism=terrorism_df[['Year','Month','Day','Country','Target','State','Region',
                               'City','Latitude','Longitude','AttackType','Kills',
                               'Wounded','Summary','Group','TargetType',
                               'WeaponType','Motive']]

# %%
global_terrorism.head()
# Out:
#    Year  Month  Day             Country                   Target    State  \
# 0  1970      7    2  Dominican Republic             Julio Guzman      NaN
# 1  1970      0    0              Mexico  Nadine Chaval, daughter  Federal
# 2  1970      1    0         Philippines                 Employee   Tarlac
# 3  1970      1    0              Greece             U.S. Embassy   Attica
# 4  1970      1    0               Japan           U.S. Consulate  Fukouka
#
#                         Region           City   Latitude   Longitude  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# 4                    East Asia        Fukouka  33.580412  130.396361
#
#                        AttackType  Kills  Wounded Summary  \
# 0                   Assassination    1.0      0.0     NaN
# 1     Hostage Taking (Kidnapping)    0.0      0.0     NaN
# 2                   Assassination    1.0      0.0     NaN
# 3               Bombing/Explosion    NaN      NaN     NaN
# 4  Facility/Infrastructure Attack    NaN      NaN     NaN
#
#                                 Group                   TargetType  \
# 0                              MANO-D  Private Citizens & Property
# 1  23rd of September Communist League      Government (Diplomatic)
# 2                             Unknown          Journalists & Media
# 3                             Unknown      Government (Diplomatic)
# 4                             Unknown      Government (Diplomatic)
#
#    WeaponType Motive
# 0     Unknown    NaN
# 1     Unknown    NaN
# 2     Unknown    NaN
# 3  Explosives    NaN
# 4  Incendiary    NaN

# %% [markdown]
# ### Total Number of Missing Values

# %%
global_terrorism.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# Target           638
# State            421
# Region             0
# City             435
# Latitude        4556
# Longitude       4557
# AttackType         0
# Kills          10313
# Wounded        16311
# Summary        66129
# Group              0
# TargetType         0
# WeaponType         0
# Motive        131130
# dtype: int64

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize=(20,40))
sns.heatmap(global_terrorism.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### Descriptive Statistics of Data

# %%
global_terrorism.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude          Kills        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# 75%    6.871033e+01       2.000000       2.000000
# max    1.793667e+02    1570.000000    8191.000000

# %% [markdown]
# ### Compute Pairwise Correlation of Columns

# %%
numeric_df = global_terrorism.select_dtypes(include='number')
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                Year     Month       Day  Latitude  Longitude     Kills  \
# Year       1.000000  0.000139  0.018254  0.166933   0.003917  0.015341
# Month      0.000139  1.000000  0.005497 -0.015978  -0.003880  0.003463
# Day        0.018254  0.005497  1.000000  0.003423  -0.002285 -0.003693
# Latitude   0.166933 -0.015978  0.003423  1.000000   0.001463 -0.018124
# Longitude  0.003917 -0.003880 -0.002285  0.001463   1.000000 -0.000562
# Kills      0.015341  0.003463 -0.003693 -0.018124  -0.000562  1.000000
# Wounded    0.015273  0.002938 -0.001268  0.015988   0.000223  0.534375
#
#             Wounded
# Year       0.015273
# Month      0.002938
# Day       -0.001268
# Latitude   0.015988
# Longitude  0.000223
# Kills      0.534375
# Wounded    1.000000

# %% [markdown]
# ### Compute the Covariance Matrix

# %%
numeric_df = global_terrorism.select_dtypes(include='number')
covariance_matrix = numeric_df.cov()
print(covariance_matrix)
# Out:
#                    Year        Month          Day     Latitude     Longitude  \
# Year         175.812496     0.006242     2.133346    40.951530  1.059590e+04
# Month          0.006242    11.480600     0.164158    -1.005279 -2.692110e+03
# Day            2.133346     0.164158    77.687385     0.559877 -4.120870e+03
# Latitude      40.951530    -1.005279     0.559877   344.816764  5.564253e+03
# Longitude  10595.897714 -2692.109846 -4120.870170  5564.252921  4.193443e+10
# Kills          2.292652     0.135442    -0.375477    -3.822593 -1.358855e+03
# Wounded        7.019333     0.357870    -0.401569    10.634340  1.740424e+03
#
#                  Kills      Wounded
# Year          2.292652     7.019333
# Month         0.135442     0.357870
# Day          -0.375477    -0.401569
# Latitude     -3.822593    10.634340
# Longitude -1358.855169  1740.424297
# Kills       133.304125   188.711482
# Wounded     188.711482  1292.358771

# %% [markdown]
# ### Printing the Stats from above Data

# %%
print('Country with the most Attacks:',global_terrorism['Country'].value_counts().idxmax())
print('City with the most Attacks:',global_terrorism['City'].value_counts().index[1])
print('Region with the most Attacks:',global_terrorism['Region'].value_counts().idxmax())
print('Year with the most Attacks:',global_terrorism['Year'].value_counts().idxmax())
print('Month with the most Attacks:',global_terrorism['Month'].value_counts().idxmax())
print('Group with the most Attacks:',global_terrorism['Group'].value_counts().index[1])
print('Most Attack Types:',global_terrorism['AttackType'].value_counts().idxmax())
# Out:
# Country with the most Attacks: Iraq
# City with the most Attacks: Baghdad
# Region with the most Attacks: Middle East & North Africa
# Year with the most Attacks: 2014
# Month with the most Attacks: 5
# Group with the most Attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %% [markdown]
# ### Visualization for Terrorist attack by Region for Every  Year

# %%
pd.crosstab(global_terrorism.Year,global_terrorism.Region).plot(kind='area',figsize=(20,10))
plt.title('Terrorist attack by region in for every  year')
plt.show()

# %% [markdown]
# ### Visualization for No. of Terrorist activities each Year

# %%
plt.subplots(figsize=(15, 5))
sns.countplot(data=global_terrorism, x='Year')
plt.xticks(rotation=90)
plt.title('No. of Terrorist activities each Year')
plt.show()

# %%
global_terrorism['Wounded'] = global_terrorism['Wounded'].fillna(0).astype(int)
global_terrorism['Kills'] = global_terrorism['Kills'].fillna(0).astype(int)
global_terrorism['Casualties'] = global_terrorism['Kills']+global_terrorism['Wounded']

# %% [markdown]
# ### Number of Occurrences of each Unique Value in the Column 'Country'

# %%
global_terrorism.Country.value_counts()[:20]
# Out:
# Country
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Sri Lanka          3022
# United States      2836
# Algeria            2743
# France             2693
# Egypt              2479
# Name: count, dtype: int64

# %% [markdown]
# ### Visualization of Top Affected Countries

# %%
plt.subplots(figsize=(30, 15))
sns.barplot(x=global_terrorism['Country'].value_counts()[:50].index, y=global_terrorism['Country'].value_counts()[:50])
plt.xticks(rotation=90)
plt.title('Top Affected Countries')
plt.show()

# %% [markdown]
# ### Visualization of Method of Attack

# %%
plt.subplots(figsize=(10, 5))
sns.countplot(x='AttackType', data=global_terrorism,
              order=global_terrorism['AttackType'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Method of Attack')
plt.show()

# %% [markdown]
# ### Visualization of Terrorist Attacks per Country

# %%
fig, axes = plt.subplots(figsize=(10, 5))
data = pd.DataFrame({'Country': global_terrorism['Country'].value_counts()[:20].index,
                     'Count': global_terrorism['Country'].value_counts()[:20].values})
sns.barplot(x='Count', y='Country', data=data)
plt.title('Terrorist Attacks per Country')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization of Terrorist Attacks per Region

# %%
fig, axes = plt.subplots(figsize=(10, 5))
data = pd.DataFrame({'Count': global_terrorism['Region'].value_counts()[:20].values,
                     'Region': global_terrorism['Region'].value_counts()[:20].index})
sns.barplot(x='Count', y='Region', data=data)
plt.title('Terrorist Attacks per Region')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization of Terrorist Attacks per Region

# %%
fig, axes = plt.subplots(figsize=(10, 5))
data = pd.DataFrame({'Count': global_terrorism['Group'].value_counts()[1:12].values,
                     'Group': global_terrorism['Group'].value_counts()[1:12].index})
sns.barplot(x='Count', y='Group', data=data)
plt.title('Most Active Terrorist Organizations')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization of Most Affected Areas

# %%
fig, axes = plt.subplots(figsize=(10, 5))
sns.barplot(x=global_terrorism['TargetType'].value_counts().values,
            y=global_terrorism['TargetType'].value_counts().index)
plt.title('Most Affected Areas')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Result of Incresed Attack in Percentage

# %%
year = global_terrorism['Year'].value_counts().to_dict()
rate = ((year[2017] - year[1970]) / year[1970]) * 100

print('Attacks Happened in 1970:', year[1970])
print('Attacks Happened in 2017:', year[2017])
print('No. of Attacks from 1970 has increased by:', np.round(rate), '% till 2017')
# Out:
# Attacks Happened in 1970: 651
# Attacks Happened in 2017: 10900
# No. of Attacks from 1970 has increased by: 1574.0 % till 2017

# %% [markdown]
# ### Visualization of Weapon Type

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=90)
sns.countplot(x='WeaponType',data=global_terrorism)
# Out:
# <Axes: xlabel='WeaponType', ylabel='count'>

# %% [markdown]
# ### Visualization of Attack type and Targeted Areas

# %%
plt.figure(figsize=(20,15))
sns.countplot(x='AttackType',hue='TargetType',data=global_terrorism)
plt.xticks(rotation=90)
plt.legend(loc='upper right')
